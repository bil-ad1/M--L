# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp
import seaborn as sb

# %%
e_c = pd.read_csv("../input/pakistans-largest-ecommerce-dataset/Pakistan Largest Ecommerce Dataset.csv")

# %%
e_c.info()

# %%
e_c.isnull().sum()

# %%
e_c.dropna(how='all',inplace=True)

# %%
e_c.shape

# %%
y16 = e_c[e_c.Year==2016].drop(["Unnamed: 21","Unnamed: 22","Unnamed: 23","Unnamed: 24","Unnamed: 25"],axis=1)

# %%
sb.barplot(x='category_name_1',y='qty_ordered',data=y16)

# %%
sb.barplot(x='qty_ordered',y='status',data=y16)

# %%
sb.scatterplot(x='Month',y='qty_ordered',data=y16)

# %%
y16.Month.unique()

# %%
sb.lineplot(x='Month',y='qty_ordered',data=y16)

# %%
sb.displot(x='Month',y='qty_ordered',data=y16)

# %%
sb.boxplot(x='Month',y='qty_ordered',data=y16)

# %%
sb.histplot(x='Month',y='qty_ordered',data=y16)

# %%
sb.jointplot(x='Month',y='qty_ordered',data=y16)

# %%
sb.stripplot(x='Month',y='qty_ordered',data=y16)

# %%
y17 = e_c[e_c.Year==2017].drop(["Unnamed: 21","Unnamed: 22","Unnamed: 23","Unnamed: 24","Unnamed: 25"],axis=1)

# %%
sb.lineplot(x='Month',y='qty_ordered',data=y17)

# %%
pp.title("Qty ord vs Sts")
sb.barplot(x='qty_ordered',y='status',data=y17)

# %%
sb.lineplot(x='qty_ordered',y='grand_total',data=y17)

# %%
y17.grand_total.sum()

# %%
e_c.drop(["Unnamed: 21","Unnamed: 22","Unnamed: 23","Unnamed: 24","Unnamed: 25"],axis=1)

# %%
sb.barplot(x='Year',y='grand_total',data=e_c)

# %%
sb.lineplot(x='Year',y='grand_total',data=e_c)

# %%
sb.barplot(x='Year',y='qty_ordered',data=e_c)

# %%
sb.histplot(x='category_name_1',y='payment_method',data=e_c)

# %%
sb.histplot(x='qty_ordered',y='payment_method',data=e_c)

# %%
sb.histplot(x='payment_method',y='status',data=e_c)

# %%
sb.barplot(x='Month',y='status',data=e_c)

# %%
sb.scatterplot(x='Month',y='status',data=e_c)

# %%
sb.barplot(y='Month',x='status',data=e_c)

# %%
e_c.corr()
